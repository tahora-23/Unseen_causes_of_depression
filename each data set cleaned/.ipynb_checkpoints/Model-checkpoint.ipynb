# %%
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import numpy as np
from sklearn.preprocessing import PowerTransformer, StandardScaler, MinMaxScaler, OneHotEncoder, LabelEncoder
from sklearn.metrics import mean_absolute_error, mean_squared_error as mse, r2_score
from sklearn.linear_model import LinearRegression

# %%
df = pd.read_csv("final3.csv", index_col=0)

# %%
df
# Out:
#         country    region  depression_rate  corruption_score  \
# 0       Albania    Europe              4.8              36.0
# 1       Algeria    Africa              4.5              33.0
# 2        Angola    Africa              3.6              33.0
# 3     Argentina  Americas              4.7              38.0
# 4       Armenia      Asia              5.0              46.0
# ..          ...       ...              ...               ...
# 125     Ukraine    Europe              6.3              33.0
# 126  Uzbekistan      Asia              4.2              31.0
# 127   Venezuela  Americas              4.2              14.0
# 128     Vietnam      Asia              4.0              42.0
# 129      Zambia    Africa              4.0              33.0
#
#      average_temperature  gini  unemployment_rate  Family size  \
# 0                  12.47  59.0               11.7         3.30
# 1                  23.61  27.6               13.6         5.05
# 2                  21.77  51.3                9.6         4.82
# 3                  15.10  42.9               11.5         3.26
# 4                   7.86  29.9               18.3         3.54
# ..                   ...   ...                ...          ...
# 125                 9.28  26.6                9.5         2.46
# 126                13.72  35.3                9.0         5.24
# 127                25.71  44.8                5.0         4.33
# 128                24.78  35.7                2.4         4.29
# 129                22.23  57.1               12.5         5.13
#
#      Public services index  crime index  litracy_rate  gender_equality  \
# 0                      4.1         5.63         97.55            0.770
# 1                      5.3         4.51         79.61            0.633
# 2                      9.1         5.29         71.16            0.657
# 3                      4.5         4.38         98.09            0.752
# 4                      3.6         3.26         99.77            0.673
# ..                     ...          ...           ...              ...
# 125                    4.3         6.18         99.76            0.714
# 126                    4.3         4.96        100.00            0.670
# 127                    8.6         6.64         95.40            0.699
# 128                    4.0         6.28         94.51            0.701
# 129                    7.8         4.93         85.12            0.726
#
#      democracy_score  Air Quality
# 0               6.08            0
# 1               3.77            1
# 2               3.66            3
# 3               6.95            0
# 4               5.35            1
# ..               ...          ...
# 125             5.81            1
# 126             2.12            1
# 127             2.76            0
# 128             2.94            1
# 129             4.86            3
#
# [130 rows x 14 columns]

# %%
df_d = pd.read_csv('demographic.csv')
df_density = df_d[['Country/Area Name','Density (per sq km)']].copy()

# %%
df_den = df_density.rename(columns={'Country/Area Name': 'country'})
df_den
# Out:
#                country  Density (per sq km)
# 0          Afghanistan                 60.2
# 1              Albania                113.2
# 2              Algeria                 18.8
# 3       American Samoa                225.4
# 4              Andorra                182.6
# ..                 ...                  ...
# 222  Wallis and Futuna                112.2
# 223          West Bank                540.9
# 224              Yemen                 59.8
# 225             Zambia                 27.2
# 226           Zimbabwe                 39.9
#
# [227 rows x 2 columns]

# %%
df_den['country'] = df_den['country'].replace({'United States': 'USA', 'Congo (Kinshasa)':'DRC', 'United Arab Emirates': 'UAE', 'United Kingdom':'UK','Bahamas, The':'Bahamas'})
df_den
# Out:
#                country  Density (per sq km)
# 0          Afghanistan                 60.2
# 1              Albania                113.2
# 2              Algeria                 18.8
# 3       American Samoa                225.4
# 4              Andorra                182.6
# ..                 ...                  ...
# 222  Wallis and Futuna                112.2
# 223          West Bank                540.9
# 224              Yemen                 59.8
# 225             Zambia                 27.2
# 226           Zimbabwe                 39.9
#
# [227 rows x 2 columns]

# %%
df_care = pd.read_excel('health_score.xlsx', index_col=0)

null_values = df_care.isnull().sum()
null_values
# Out:
# country              0
# care_system_score    0
# dtype: int64

# %%
df_care
# Out:
#                country  care_system_score
# 1              Belgium               83.8
# 2                Japan               83.2
# 3               Sweden               83.1
# 4          Switzerland               82.4
# 5               Norway               82.2
# ..                 ...                ...
# 122             Zambia               41.7
# 123              Benin               40.9
# 124  Equatorial Guinea               40.6
# 125           Djibouti               40.5
# 126              Kenya               40.5
#
# [126 rows x 2 columns]

# %%
df_poverty = pd.read_csv('poverty-rate.csv')
df_poverty
# Out:
#                country  percPoverty  dataYear  lessThan10  lessThan550
# 0    Equatorial Guinea         76.8      2006         NaN          NaN
# 1          South Sudan         76.4      2016       99.70        98.44
# 2           Madagascar         70.7      2012       99.41        97.09
# 3        Guinea-Bissau         69.3      2010       96.56        92.21
# 4              Eritrea         69.0      1993         NaN          NaN
# ..                 ...          ...       ...         ...          ...
# 167             Guyana          NaN      2019       53.95        23.84
# 168           Suriname          NaN      2019       62.34        38.31
# 169         Cape Verde          NaN      2019       65.72        34.23
# 170             Belize          NaN      2019       77.63        53.77
# 171              Nauru          NaN      2019       67.19        27.29
#
# [172 rows x 5 columns]

# %%
df_poverty_new = df_poverty[['country', 'percPoverty']]

# %%
df_pov = df_poverty_new.rename(columns={'percPoverty': 'percentage_poverty'})

# %%
column_values = df_care['country'].tolist()
# Display the column values
print(column_values)
# Out:
# ['Belgium', 'Japan', 'Sweden', 'Switzerland', 'Norway', 'Germany', 'Iceland', 'Finland', 'France', 'Malta', 'Denmark', 'United Kingdom', 'Cuba', 'Luxembourg', 'Netherlands', 'Austria', 'Ireland', 'Czech Republic', 'Hong Kong', 'Taiwan', 'Australia', 'South Korea', 'Uruguay', 'Italy', 'Slovenia', 'Israel', 'Belarus', 'Argentina', 'New Zealand', 'United States of America', 'Spain', 'Seychelles', 'Estonia', 'Croatia', 'Canada', 'Hungary', 'Latvia', 'Lithuania', 'Singapore', 'Portugal', 'Romania', 'Qatar', 'Slovakia', 'Thailand', 'United Arab Emirates', 'Russia', 'Bulgaria', 'Uzbekistan', 'Chile', 'Greece', "People's Republic of China", 'Kazakhstan', 'Armenia', 'Cyprus', 'Republic of Macedonia', 'Kuwait', 'Colombia', 'Bahrain', 'Oman', 'Turkmenistan', 'Montenegro', 'Trinidad and Tobago', 'Serbia', 'Malaysia', 'Brazil', 'Costa Rica', 'Kyrgyzstan', 'Ukraine', 'Poland', 'Rwanda', 'Jordan', 'Georgia', 'Saudi Arabia', 'Mauritius', 'Moldova', 'Tajikistan', 'Mexico', 'Azerbaijan', 'Sri Lanka', 'Lebanon', 'Suriname', 'South Africa', 'Guyana', 'Botswana', 'Libya', 'Turkey', 'Vietnam', 'Indonesia', 'Philippines', 'Albania', 'Cambodia', 'Bosnia and Herzegovina', 'Algeria', 'Iran', 'Panama', 'Eswatini', 'Syria', 'Belize', 'Dominican Republic', 'Mongolia', 'El Salvador', 'Namibia', 'Peru', 'Jamaica', 'Nicaragua', 'Tunisia', 'Venezuela', 'Ecuador', 'Mozambique', 'Myanmar', 'Burundi', 'Gabon', 'Paraguay', 'Morocco', 'São Tomé and Príncipe', 'Malawi', 'India', 'Ghana', 'Zimbabwe', 'Iraq', 'Laos', 'Zambia', 'Benin', 'Equatorial Guinea', 'Djibouti', 'Kenya']

# %%
df_care['country'] = df_care['country'].replace({'United States of America': 'USA', 'United Arab Emirates': 'UAE', 'United Kingdom':'UK',"People's Republic of China": "China" })

# %%
df_pov['country'] = df_pov['country'].replace({'United States': 'USA', 'DR Congo':'DRC', 'United Arab Emirates': 'UAE', 'United Kingdom':'UK'})
df_pov
# Out:
#                country  percentage_poverty
# 0    Equatorial Guinea                76.8
# 1          South Sudan                76.4
# 2           Madagascar                70.7
# 3        Guinea-Bissau                69.3
# 4              Eritrea                69.0
# ..                 ...                 ...
# 167             Guyana                 NaN
# 168           Suriname                 NaN
# 169         Cape Verde                 NaN
# 170             Belize                 NaN
# 171              Nauru                 NaN
#
# [172 rows x 2 columns]

# %%
null_values = df_pov.isnull().sum()
null_values
# Out:
# country                0
# percentage_poverty    13
# dtype: int64

# %%
null_values = df_pov.isnull().sum()

# %%
df_pov.dropna(axis=0, inplace=True)

# %%
df_merge = df.merge(df_den, on='country')
df_merge
# Out:
#         country    region  depression_rate  corruption_score  \
# 0       Albania    Europe              4.8              36.0
# 1       Algeria    Africa              4.5              33.0
# 2        Angola    Africa              3.6              33.0
# 3     Argentina  Americas              4.7              38.0
# 4       Armenia      Asia              5.0              46.0
# ..          ...       ...              ...               ...
# 119     Ukraine    Europe              6.3              33.0
# 120  Uzbekistan      Asia              4.2              31.0
# 121   Venezuela  Americas              4.2              14.0
# 122     Vietnam      Asia              4.0              42.0
# 123      Zambia    Africa              4.0              33.0
#
#      average_temperature  gini  unemployment_rate  Family size  \
# 0                  12.47  59.0               11.7         3.30
# 1                  23.61  27.6               13.6         5.05
# 2                  21.77  51.3                9.6         4.82
# 3                  15.10  42.9               11.5         3.26
# 4                   7.86  29.9               18.3         3.54
# ..                   ...   ...                ...          ...
# 119                 9.28  26.6                9.5         2.46
# 120                13.72  35.3                9.0         5.24
# 121                25.71  44.8                5.0         4.33
# 122                24.78  35.7                2.4         4.29
# 123                22.23  57.1               12.5         5.13
#
#      Public services index  crime index  litracy_rate  gender_equality  \
# 0                      4.1         5.63         97.55            0.770
# 1                      5.3         4.51         79.61            0.633
# 2                      9.1         5.29         71.16            0.657
# 3                      4.5         4.38         98.09            0.752
# 4                      3.6         3.26         99.77            0.673
# ..                     ...          ...           ...              ...
# 119                    4.3         6.18         99.76            0.714
# 120                    4.3         4.96        100.00            0.670
# 121                    8.6         6.64         95.40            0.699
# 122                    4.0         6.28         94.51            0.701
# 123                    7.8         4.93         85.12            0.726
#
#      democracy_score  Air Quality  Density (per sq km)
# 0               6.08            0                113.2
# 1               3.77            1                 18.8
# 2               3.66            3                 28.9
# 3               6.95            0                 17.0
# 4               5.35            1                106.0
# ..               ...          ...                  ...
# 119             5.81            1                 74.8
# 120             2.12            1                 73.7
# 121             2.76            0                 34.6
# 122             2.94            1                338.0
# 123             4.86            3                 27.2
#
# [124 rows x 15 columns]

# %%
merged_df = df_merge.merge(df_pov, on = 'country')

# %%
merged_df
# Out:
#        country    region  depression_rate  corruption_score  \
# 0      Albania    Europe              4.8              36.0
# 1      Algeria    Africa              4.5              33.0
# 2       Angola    Africa              3.6              33.0
# 3    Argentina  Americas              4.7              38.0
# 4      Armenia      Asia              5.0              46.0
# ..         ...       ...              ...               ...
# 95     Ukraine    Europe              6.3              33.0
# 96  Uzbekistan      Asia              4.2              31.0
# 97   Venezuela  Americas              4.2              14.0
# 98     Vietnam      Asia              4.0              42.0
# 99      Zambia    Africa              4.0              33.0
#
#     average_temperature  gini  unemployment_rate  Family size  \
# 0                 12.47  59.0               11.7         3.30
# 1                 23.61  27.6               13.6         5.05
# 2                 21.77  51.3                9.6         4.82
# 3                 15.10  42.9               11.5         3.26
# 4                  7.86  29.9               18.3         3.54
# ..                  ...   ...                ...          ...
# 95                 9.28  26.6                9.5         2.46
# 96                13.72  35.3                9.0         5.24
# 97                25.71  44.8                5.0         4.33
# 98                24.78  35.7                2.4         4.29
# 99                22.23  57.1               12.5         5.13
#
#     Public services index  crime index  litracy_rate  gender_equality  \
# 0                     4.1         5.63         97.55            0.770
# 1                     5.3         4.51         79.61            0.633
# 2                     9.1         5.29         71.16            0.657
# 3                     4.5         4.38         98.09            0.752
# 4                     3.6         3.26         99.77            0.673
# ..                    ...          ...           ...              ...
# 95                    4.3         6.18         99.76            0.714
# 96                    4.3         4.96        100.00            0.670
# 97                    8.6         6.64         95.40            0.699
# 98                    4.0         6.28         94.51            0.701
# 99                    7.8         4.93         85.12            0.726
#
#     democracy_score  Air Quality  Density (per sq km)  percentage_poverty
# 0              6.08            0                113.2                14.3
# 1              3.77            1                 18.8                 5.5
# 2              3.66            3                 28.9                32.3
# 3              6.95            0                 17.0                35.5
# 4              5.35            1                106.0                26.4
# ..              ...          ...                  ...                 ...
# 95             5.81            1                 74.8                 1.1
# 96             2.12            1                 73.7                14.1
# 97             2.76            0                 34.6                33.1
# 98             2.94            1                338.0                 6.7
# 99             4.86            3                 27.2                54.4
#
# [100 rows x 16 columns]

# %%
y = merged_df[['depression_rate']]

# %%
X = merged_df[['corruption_score', 'average_temperature',
       'gini', 'unemployment_rate', 'Family size', 'Public services index',
       'crime index', 'litracy_rate', 'gender_equality', 'democracy_score',
       'Air Quality', 'Density (per sq km)', 'percentage_poverty',]]

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X,y,test_size=0.3, random_state=42)

# %%
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.fit_transform(X_test)
y_test_scaled = scaler.fit_transform(y_test)
y_train_scaled = scaler.fit_transform(y_test)

# %%
plt.figure(figsize=(10, 6))
for i in range(X_scaled.shape[1]):
    plt.hist(X_scaled[:, i], bins=20, alpha=0.5, label='variables')
plt.xlabel('Scaled Values')
plt.ylabel('Frequency')
plt.title('Distribution of Scaled Features')
plt.legend()
plt.show()

# %%
#pt = PowerTransformer()
#pt.fit(X_train)
#pt.fit(X_test)

#X_train_transformed = pt.transform(X_train)
#X_test_transformed = pt.transform(X_test)

# %%
lm = LinearRegression()
model = lm.fit(X_train_scaled, y_train)

# %%
print(model.coef_)
print(model.intercept_)
# Out:
# [[-0.1202542   0.02279959 -0.08364614  0.07463115 -0.40158404  0.13164342
#   -0.06155287  0.11962368 -0.08329501  0.24635403  0.06747825 -0.07821185
#   -0.0484011 ]]
# [4.55014286]

# %%
y_pred = model.predict(X_test_scaled)

# %%
y_test = np.array(y_test).ravel()
y_pred = np.array(y_pred).ravel()
compare = pd.DataFrame({'y_test':list(y_test), 'y_pred':list(y_pred)})

# %%
import matplotlib.pyplot as plt

plt.scatter(y_test, y_pred)
plt.plot([min(y_test), max(y_test)], [min(y_pred), max(y_pred)], color='red', linestyle='--')
plt.xlabel('Actual Values')
plt.ylabel('Predicted Values')
plt.title('Scatter Plot of Actual vs. Predicted Values with Line')
plt.show()

# %%
compare
# Out:
#     y_test    y_pred
# 0      5.2  5.074466
# 1      4.4  4.578400
# 2      3.9  4.326534
# 3      3.7  4.748090
# 4      4.5  4.459685
# 5      5.7  5.307464
# 6      4.7  4.794089
# 7      5.0  4.872170
# 8      4.8  4.836151
# 9      4.8  4.508849
# 10     4.2  3.705015
# 11     4.4  4.346500
# 12     4.8  4.832281
# 13     5.6  5.129296
# 14     3.9  3.946973
# 15     5.0  4.976909
# 16     5.7  4.902247
# 17     5.0  5.019443
# 18     5.1  5.266349
# 19     5.9  5.049623
# 20     3.2  3.594084
# 21     3.8  3.763076
# 22     5.0  4.895184
# 23     5.1  5.050055
# 24     4.7  4.708872
# 25     3.6  3.624587
# 26     3.7  3.940482
# 27     4.2  4.024372
# 28     5.6  4.637197
# 29     4.2  3.585842

# %%
# Evaluate the model

mse = np.square(np.subtract(y_test,y_pred)).mean()
rmse = np.sqrt(mse)
mae = mean_absolute_error(y_test, y_pred)
r2 = r2_score(y_test, y_pred)

# %%
print('MSE: ', mse)
print('RMSE: ', rmse)
print('MAE: ', mae)
print('R2: ', r2)
# Out:
# MSE:  0.1673163937127498
# RMSE:  0.4090432663090175
# MAE:  0.2776128420187204
# R2:  0.6527424722316326

# %%
coefficients = model.coef_.flatten()
feature_importance = pd.DataFrame({'Features': X.columns, 'Coefficient': coefficients})

# %%
feature_importance
# Out:
#                  Features  Coefficient
# 0        corruption_score    -0.120254
# 1     average_temperature     0.022800
# 2                    gini    -0.083646
# 3       unemployment_rate     0.074631
# 4             Family size    -0.401584
# 5   Public services index     0.131643
# 6             crime index    -0.061553
# 7            litracy_rate     0.119624
# 8         gender_equality    -0.083295
# 9         democracy_score     0.246354
# 10            Air Quality     0.067478
# 11    Density (per sq km)    -0.078212
# 12     percentage_poverty    -0.048401

# %%
plt.figure(figsize= (10,8))
plt.barh(feature_importance['Features'], feature_importance['Coefficient'])
plt.xlabel('Coefficient')
plt.ylabel('Feature')
plt.title('Feature Importance ')
plt.show()

# %%
import pandas as pd
import statsmodels.api as sm
from statsmodels.stats.outliers_influence import variance_inflation_factor

# Calculate the VIF for each feature
vif = pd.DataFrame()
vif["Variable"] = X.columns
vif["VIF"] = [variance_inflation_factor(X.values, i) for i in range(X.shape[1])]

print(vif)
# Out:
#                  Variable         VIF
# 0        corruption_score   35.875441
# 1     average_temperature   13.960221
# 2                    gini   59.047435
# 3       unemployment_rate    4.219299
# 4             Family size   24.595686
# 5   Public services index   43.170657
# 6             crime index   46.201557
# 7            litracy_rate  100.925933
# 8         gender_equality  201.798978
# 9         democracy_score   33.855271
# 10            Air Quality    2.661913
# 11    Density (per sq km)    2.118080
# 12     percentage_poverty    9.991265

# %%
import matplotlib.pyplot as plt
plt.scatter(vif['VIF'], vif['Variable'])
plt.xlabel('Variance Inflation Factor (VIF)')
plt.ylabel('Features')
plt.title('Scatter Plot of VIF values')
plt.show()
